# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers=headers).text

# %%
soup = BeautifulSoup(webpage, "lxml")

# %%
# print(soup.prettify())
# soup.find_all("h1")[0].text.strip()
# len(soup.find_all("h2"))
# for i in soup.find_all("h2"):
  # print(i.text.strip())
# soup.find_all("div", class_= "companyCardWrapper__companyRating")
# soup.find_all("span", class_= "companyCardWrapper__ActionCount")

# %%
company = soup.find_all("div", class_="companyCardWrapper")

# %%
len(company)
# Out:
# 20

# %%
name = []
rating = []
reviews = []
other_info = []

for i in company:
    name.append(i.find("h2").text.strip())
    rating.append(i.find("div", class_= "companyCardWrapper__companyRating").text.strip())
    reviews.append(i.find("span", class_= "companyCardWrapper__ActionCount").text.strip())
    other_info.append(i.find("span", class_="companyCardWrapper__interLinking").text.strip())

d = {"name":name, "rating": rating, "reviews": reviews, "other_info" :other_info}
df = pd.DataFrame(d)
df
# Out:
#                        name rating reviews  \
# 0                       TCS    3.8   66.9k
# 1                 Accenture    4.1   42.7k
# 2                 Cognizant    3.9   38.5k
# 3                     Wipro    3.8   35.5k
# 4                ICICI Bank    4.0     31k
# 5                 HDFC Bank    3.9   30.7k
# 6                   Infosys    3.9   29.2k
# 7                 Capgemini    3.8   27.1k
# 8             Tech Mahindra    3.7   25.4k
# 9                   HCLTech    3.7   24.9k
# 10                  Genpact    3.9   24.3k
# 11                Axis Bank    3.8   20.4k
# 12   Concentrix Corporation    3.9   20.1k
# 13                   Amazon    4.1   19.3k
# 14             Reliance Jio    3.9   18.6k
# 15                      IBM    4.1   18.6k
# 16  Larsen & Toubro Limited    4.0   17.4k
# 17          Reliance Retail    3.9   16.8k
# 18   HDB Financial Services    4.0   16.4k
# 19          Teleperformance    3.6   15.8k
#
# ...

# %%
final = pd.DataFrame()

for j in range(1,500):

    url = "https://www.ambitionbox.com/list-of-companies?page={}".format(j)

    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get(url, headers=headers).text

    soup = BeautifulSoup(webpage, "lxml")
    company = soup.find_all("div", class_="companyCardWrapper")

    name = []
    rating = []
    reviews = []
    other_info = []

    for i in company:
        name.append(i.find("h2").text.strip())
        rating.append(i.find("div", class_= "companyCardWrapper__companyRating").text.strip())
        reviews.append(i.find("span", class_= "companyCardWrapper__ActionCount").text.strip())
        other_info.append(i.find("span", class_="companyCardWrapper__interLinking").text.strip())

    d = {"name":name,
         "rating": rating,
         "reviews": reviews,
         "other_info" :other_info}
    df = pd.DataFrame(d)

    final = final.append(df, ignore_index=True)
# Out:
# <ipython-input-97-b720934907ad>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-97-b720934907ad>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-97-b720934907ad>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-97-b720934907ad>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# ...

# %%
final
# Out:
#                             name rating reviews  \
# 0                            TCS    3.8   66.9k
# 1                      Accenture    4.1   42.7k
# 2                      Cognizant    3.9   38.5k
# 3                          Wipro    3.8   35.5k
# 4                     ICICI Bank    4.0     31k
# ...                          ...    ...     ...
# 9975        Maya Digital Studios    3.3      66
# 9976            Mukand Engineers    4.3      66
# 9977              Dit University    3.6      66
# 9978  Viaante Business Solutions    3.5      66
# 9979   Santa Monica Study Abroad    3.4      66
#
#                                              other_info
# 0     IT Services & Consulting | 1 Lakh+ Employees |...
# 1     IT Services & Consulting | 1 Lakh+ Employees |...
# 2     IT Services & Consulting | 1 Lakh+ Employees |...
# 3     IT Services & Consulting | 1 Lakh+ Employees |...
# 4     Banking | 1 Lakh+ Employees | Public | 29 year...
# ...
